# %% [markdown]
# <a href="https://colab.research.google.com/github/flowergum/NN2/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from matplotlib import pyplot as plt
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Conv2D, LeakyReLU, Flatten, Dense
from tensorflow.keras.layers import Reshape, Conv2DTranspose, Dropout
from tensorflow.keras.layers import Embedding, Concatenate, Input, BatchNormalization
from tensorflow.compat.v1.train import AdamOptimizer
from tensorflow.keras.initializers import RandomNormal

# %%
gpus = tf.config.experimental.list_physical_devices("GPU")
try:
  logical_gpus = tf.config.experimental.list_logical_devices("GPU")
  print(f"Physical GPUs {len(gpus)}\nLogical GPUs {len(logical_gpus)}")
except RuntimeError as e:
  print(e)
# Out:
# Physical GPUs 1
# Logical GPUs 1

# %%
def create_discriminator(in_shape=(28,28,1), n_classes=10):
    in_label = Input(shape=(1,))  # input layer
    li = Embedding(n_classes, 50)(in_label)  # embedding for categorical input
    n_nodes = in_shape[0] * in_shape[1]  # scale up to image dimensions
    li = Dense(n_nodes)(li)
    li = Reshape((in_shape[0], in_shape[1], 1))(li)
    in_image = Input(shape=in_shape)  # image input
    merge = Concatenate()([in_image, li])
    fe = Conv2D(filters=128,
                kernel_size=(3,3),
                strides=(2,2),
                padding='same',
                activation=LeakyReLU(alpha=0.2)
                )(merge)  # downsample
    fe = Conv2D(filters=128,
                kernel_size=(3,3),
                strides=(2,2),
                padding='same',
                activation=LeakyReLU(alpha=0.2)
                )(fe)
    fe = Flatten()(fe)  # Flatten feature maps
    fe = Dropout(0.4)(fe)  # Regularization via dropout
    out_layer = Dense(1, activation='sigmoid')(fe)  # Output
    
    model = Model([in_image, in_label], out_layer)  # Creating model
    model.compile(optimizer=AdamOptimizer(learning_rate=0.0002, beta1=0.5), loss='binary_crossentropy', metrics=['accuracy'])
    return model

# %%
def create_generator(latent_dim=100, n_classes=10):
    in_label = Input(shape=(1,))  # label input
    li = Embedding(n_classes, 50)(in_label) # embedding for categorical input
    n_nodes = 7*7  # linear multiplication
    li = Dense(n_nodes)(li)
    li = Reshape((7, 7, 1))(li)
    in_lat = Input(shape=(latent_dim,))  # image generator input
    
    n_nodes = 128*7*7  # foundation for 7x7 image
    gen = Dense(n_nodes, activation=LeakyReLU(alpha=0.2))(in_lat)
    gen = Reshape((7, 7, 128))(gen)
    merge = Concatenate()([gen, li])  # merge image gen and label input
    
    gen = Conv2DTranspose(filters=128,
                          kernel_size=(3,3),
                          strides=(2,2),
                          padding='same',
                          activation=LeakyReLU(alpha=0.2)
                          )(merge)  # upsampling to 14x14
    gen = Conv2DTranspose(filters=128,
                          kernel_size=(3,3),
                          strides=(2,2),
                          padding='same',
                          activation=LeakyReLU(alpha=0.2)
                          )(gen)  # updampling to 28x28
    out_layer = Conv2D(filters=1,
                       kernel_size=(7,7),
                       activation='tanh',
                       padding='same'
                       )(gen)  # output
    model = Model([in_lat, in_label], out_layer)  # define model
    return model

# %%
def create_gan(generator, discriminator):
    # make weights in the discriminator not trainable
    discriminator.trainable = False
    # get noise and label inputs from generator
    gen_noise, gen_label = generator.input
    # get image output from the generator model
    gen_output = generator.output
    # connect image output and label input from generator as inputs to discriminator
    gan_output = discriminator([gen_output, gen_label])
    # define gan model as taking noise and label and outputting a classification
    model = Model([gen_noise, gen_label], gan_output)
    model.compile(loss='binary_crossentropy', optimizer=AdamOptimizer(learning_rate=0.0002, beta1=0.5))
    return model

# %%
def load_real_data(dataset):
    # Loading data
    (X_train, y_train), (X_test, y_test) = dataset.load_data()
    # We don't need separate test data so we can add it to our training data
    X_train = np.concatenate((X_train, X_test), axis=0)
    y_train = np.concatenate((y_train, y_test), axis=0)
    # Conv2D awaits 3-dimensional input data (color channel) so, we must add 1 axis
    X_train = np.expand_dims(X_train, axis=-1)
    # Rescale our data from [0, 255] to [-1,1]
    X_train = X_train.astype('float32')
    X_train = (X_train - 127.5) / 127.5
    return [X_train, y_train]

# %%
def gen_real_batch(dataset, n_samples):
    X_train, y_train = dataset
    # Generate n random indexes
    ix = np.random.randint(0, X_train.shape[0], n_samples)
    # Select n random images from our imageset
    X = X_train[ix]
    labels = y_train[ix]
    y = np.ones(n_samples)
    return [X, labels], y

# %%
# Create n random latent-space vectors
def gen_latent_vecs(n_samples, latent_dim=100, n_classes=10):
    latent_vecs = np.random.normal(0, 1, [n_samples, latent_dim])
    labels = np.random.randint(0, n_classes, n_samples)
    return [latent_vecs, labels]

# %%
def gen_fake_batch(generator, n_samples, latent_dim=100, n_classes=10):
    [latent_vecs, labels] = gen_latent_vecs(n_samples, latent_dim, n_classes)
    X = generator.predict([latent_vecs, labels])
    y = np.zeros(n_samples)
    return [X, labels], y

# %%
def gen_train_batch(generator, dataset, batch_size, latent_dim=100, n_classes=10):
    half_batch_size = batch_size // 2
    # Get a half batch of real samples
    [X_real, real_labels], y_real = gen_real_batch(dataset, half_batch_size)
    # Get a half batch of fake samples
    [X_fake, fake_labels], y_fake = gen_fake_batch(generator, half_batch_size, \
                                                   latent_dim, n_classes)
    # Make a mixed batch
    X = np.concatenate((X_real, X_fake), axis=0)
    y = np.concatenate((y_real, y_fake), axis=0)
    labels = np.concatenate((real_labels, fake_labels), axis=0)
    # Shuffle real and fake images
    shuffle = np.random.randint(0, batch_size, batch_size)
    X = X[shuffle]
    y = y[shuffle]
    labels = labels[shuffle]
    return [X, labels], y

# %%
def print_generated_images(generator, h, w, latent_dim=100):
    n = h*w
    X, _ = gen_latent_vecs(n, latent_dim)
    labels = np.asarray([x for _ in range(h) for x in range(w)])
    y_p = generator.predict([X, labels])

    fig = plt.figure(figsize=(20,10))
    for i in range(n):
        plt.subplot(h, w, 1 + i)
        plt.axis('off')
        plt.title("label: {}".format(labels[i]))
        plt.imshow(y_p[i, :, :, 0], cmap='gray_r')
    plt.show()

# %%
def train(generator, discriminator, gan, dataset, latent_dim, n_epoches=100, \
          batch_size=128, n_classes=10):
    X_train, y_train = dataset
    n_batches = X_train.shape[0] // batch_size
    half_batch_size = batch_size // 2

    for i in range(n_epoches):
        for j in range(n_batches):
            # Train discriminator
            [X_d, labels_d], y_d = gen_train_batch(generator, dataset, \
                                                   batch_size, latent_dim)
            d_loss, d_acc = discriminator.train_on_batch([X_d, labels_d], y_d)
            # Train generator
            [X_gan, labels] = gen_latent_vecs(batch_size, latent_dim)
            y_gan = np.ones(batch_size)
            g_loss = gan.train_on_batch([X_gan, labels], y_gan)

            print('\rEpoch: >%d, Batch: %d/%d, Dis_loss=%.3f, Dis_accuracy=%.3f Gen_loss=%.3f' % (i+1, j+1, n_batches, d_loss, d_acc, g_loss), end='')
        print()
        if i == 0 or i == 1 or (i+1) % 20 == 0:
            print_generated_images(generator, 4, 10, latent_dim)

# %%
latent_dim = 100
#Создаем дискриминатор
model_discriminator = create_discriminator()
model_generator = create_generator()
x_train, y_train = gen_train_batch(model_generator, load_real_data(mnist), 200)


#Показать, что выборка норм
#x, y = x_train
#for i in range(128):
#    print(y_train[i])
#    plt.title(y[i])
#    plt.imshow(np.reshape(x[i], (28, 28,)), cmap=plt.get_cmap('gray_r'))
#    plt.show()

history = model_discriminator.fit(x_train, y_train, epochs = 200, verbose=0)

#########
plt.figure(figsize=(16,10))
plt.xlabel('Epochs')
plt.ylabel("binary_crossentropy")
plt.plot(history.epoch, history.history["accuracy"])
plt.xlim([0,max(history.epoch)])
plt.show()
#########

# %%
model_gan = create_gan(model_generator, model_discriminator)
model_gan.save_weights("drive/My Drive/output_2/gan_initial.h5")

# %%
def train_gan(gan_model, latent_dim, n_epochs=10000, n_batch=128):
    # manually enumerate epochs
    for i in range(n_epochs):
        # prepare points in latent space as input for the generator
        x_gan = gen_latent_vecs(n_batch)
        # create inverted labels for the fake samples
        y_gan = np.ones((n_batch, 1))
        # update the generator via the discriminator's error
        gan_model.train_on_batch(x_gan, y_gan)

#model_gan.load_weights("drive/My Drive/output/gan_initial.h5")
train_gan(model_gan, 100, n_epochs = 200)

# %%
model_gan.load_weights("drive/My Drive/output_2/gan_initial.h5")
train(model_generator, model_discriminator, model_gan, load_real_data(mnist), 100)
# Out:
# Epoch: >1, Batch: 546/546, Dis_loss=0.535, Dis_accuracy=0.781 Gen_loss=1.201
# Epoch: >2, Batch: 546/546, Dis_loss=0.476, Dis_accuracy=0.828 Gen_loss=1.377
# Epoch: >3, Batch: 546/546, Dis_loss=0.587, Dis_accuracy=0.680 Gen_loss=1.091
# Epoch: >4, Batch: 546/546, Dis_loss=0.561, Dis_accuracy=0.703 Gen_loss=0.882
# Epoch: >5, Batch: 546/546, Dis_loss=0.631, Dis_accuracy=0.664 Gen_loss=1.094
# Epoch: >6, Batch: 546/546, Dis_loss=0.505, Dis_accuracy=0.789 Gen_loss=1.002
# Epoch: >7, Batch: 546/546, Dis_loss=0.575, Dis_accuracy=0.727 Gen_loss=1.507
# Epoch: >8, Batch: 546/546, Dis_loss=0.532, Dis_accuracy=0.727 Gen_loss=1.161
# Epoch: >9, Batch: 546/546, Dis_loss=0.547, Dis_accuracy=0.781 Gen_loss=0.980
# Epoch: >10, Batch: 546/546, Dis_loss=0.504, Dis_accuracy=0.750 Gen_loss=0.858
# Epoch: >11, Batch: 546/546, Dis_loss=0.510, Dis_accuracy=0.789 Gen_loss=1.254
# Epoch: >12, Batch: 546/546, Dis_loss=0.569, Dis_accuracy=0.695 Gen_loss=1.136
# Epoch: >13, Batch: 546/546, Dis_loss=0.682, Dis_accuracy=0.602 Gen_loss=1.044
# Epoch: >14, Batch: 546/546, Dis_loss=0.548, Dis_accuracy=0.742 Gen_loss=1.214
# Epoch: >15, Batch: 546/546, Dis_loss=0.559, Dis_accuracy=0.719 Gen_loss=0.861
# Epoch: >16, Batch: 546/546, Dis_loss=0.628, Dis_accuracy=0.672 Gen_loss=0.853
# Epoch: >17, Batch: 546/546, Dis_loss=0.604, Dis_accuracy=0.602 Gen_loss=1.305
# Epoch: >18, Batch: 546/546, Dis_loss=0.576, Dis_accuracy=0.688 Gen_loss=1.245
# Epoch: >19, Batch: 546/546, Dis_loss=0.575, Dis_accuracy=0.727 Gen_loss=0.934
# Epoch: >20, Batch: 546/546, Dis_loss=0.564, Dis_accuracy=0.648 Gen_loss=0.864
# Epoch: >21, Batch: 546/546, Dis_loss=0.570, Dis_accuracy=0.688 Gen_loss=0.945
# Epoch: >22, Batch: 546/546, Dis_loss=0.573, Dis_accuracy=0.703 Gen_loss=0.882
# Epoch: >23, Batch: 546/546, Dis_loss=0.554, Dis_accuracy=0.719 Gen_loss=1.051
# Epoch: >24, Batch: 546/546, Dis_loss=0.566, Dis_accuracy=0.711 Gen_loss=1.483
# Epoch: >25, Batch: 546/546, Dis_loss=0.565, Dis_accuracy=0.664 Gen_loss=0.809
# Epoch: >26, Batch: 546/546, Dis_loss=0.472, Dis_accuracy=0.781 Gen_loss=1.258
# Epoch: >27, Batch: 546/546, Dis_loss=0.605, Dis_accuracy=0.680 Gen_loss=0.834
# Epoch: >28, Batch: 546/546, Dis_loss=0.590, Dis_accuracy=0.664 Gen_loss=1.244
# Epoch: >29, Batch: 546/546, Dis_loss=0.499, Dis_accuracy=0.766 Gen_loss=1.113
# Epoch: >30, Batch: 546/546, Dis_loss=0.586, Dis_accuracy=0.711 Gen_loss=0.779
# Epoch: >31, Batch: 546/546, Dis_loss=0.562, Dis_accuracy=0.703 Gen_loss=1.083
# Epoch: >32, Batch: 546/546, Dis_loss=0.611, Dis_accuracy=0.664 Gen_loss=0.870
# Epoch: >33, Batch: 546/546, Dis_loss=0.544, Dis_accuracy=0.695 Gen_loss=1.001
# Epoch: >34, Batch: 546/546, Dis_loss=0.530, Dis_accuracy=0.734 Gen_loss=0.740
# Epoch: >35, Batch: 546/546, Dis_loss=0.558, Dis_accuracy=0.703 Gen_loss=1.230
# Epoch: >36, Batch: 546/546, Dis_loss=0.593, Dis_accuracy=0.719 Gen_loss=0.778
# Epoch: >37, Batch: 546/546, Dis_loss=0.543, Dis_accuracy=0.695 Gen_loss=0.852
# Epoch: >38, Batch: 546/546, Dis_loss=0.583, Dis_accuracy=0.633 Gen_loss=0.985
# Epoch: >39, Batch: 546/546, Dis_loss=0.630, Dis_accuracy=0.609 Gen_loss=0.897
# Epoch: >40, Batch: 546/546, Dis_loss=0.617, Dis_accuracy=0.625 Gen_loss=1.024
# Epoch: >41, Batch: 546/546, Dis_loss=0.509, Dis_accuracy=0.758 Gen_loss=0.873
# Epoch: >42, Batch: 546/546, Dis_loss=0.585, Dis_accuracy=0.664 Gen_loss=1.327
# Epoch: >43, Batch: 546/546, Dis_loss=0.655, Dis_accuracy=0.594 Gen_loss=0.960
# Epoch: >44, Batch: 546/546, Dis_loss=0.535, Dis_accuracy=0.727 Gen_loss=1.589
# Epoch: >45, Batch: 546/546, Dis_loss=0.603, Dis_accuracy=0.664 Gen_loss=0.954
# Epoch: >46, Batch: 546/546, Dis_loss=0.616, Dis_accuracy=0.656 Gen_loss=1.095
# Epoch: >47, Batch: 546/546, Dis_loss=0.571, Dis_accuracy=0.672 Gen_loss=0.811
# Epoch: >48, Batch: 546/546, Dis_loss=0.607, Dis_accuracy=0.680 Gen_loss=1.035
# Epoch: >49, Batch: 546/546, Dis_loss=0.706, Dis_accuracy=0.586 Gen_loss=0.855
# Epoch: >50, Batch: 546/546, Dis_loss=0.512, Dis_accuracy=0.742 Gen_loss=1.124
# Epoch: >51, Batch: 546/546, Dis_loss=0.520, Dis_accuracy=0.695 Gen_loss=1.320
# Epoch: >52, Batch: 546/546, Dis_loss=0.564, Dis_accuracy=0.703 Gen_loss=1.052
# Epoch: >53, Batch: 546/546, Dis_loss=0.618, Dis_accuracy=0.641 Gen_loss=1.047
# Epoch: >54, Batch: 546/546, Dis_loss=0.614, Dis_accuracy=0.656 Gen_loss=0.935
# Epoch: >55, Batch: 546/546, Dis_loss=0.598, Dis_accuracy=0.656 Gen_loss=0.949
# Epoch: >56, Batch: 546/546, Dis_loss=0.574, Dis_accuracy=0.703 Gen_loss=1.088
# Epoch: >57, Batch: 546/546, Dis_loss=0.678, Dis_accuracy=0.602 Gen_loss=0.725
# Epoch: >58, Batch: 546/546, Dis_loss=0.700, Dis_accuracy=0.547 Gen_loss=0.880
# Epoch: >59, Batch: 546/546, Dis_loss=0.614, Dis_accuracy=0.695 Gen_loss=1.149
# Epoch: >60, Batch: 546/546, Dis_loss=0.602, Dis_accuracy=0.633 Gen_loss=1.087
# Epoch: >61, Batch: 546/546, Dis_loss=0.563, Dis_accuracy=0.688 Gen_loss=0.725
# Epoch: >62, Batch: 546/546, Dis_loss=0.522, Dis_accuracy=0.680 Gen_loss=0.857
# Epoch: >63, Batch: 546/546, Dis_loss=0.617, Dis_accuracy=0.648 Gen_loss=1.092
# Epoch: >64, Batch: 546/546, Dis_loss=0.634, Dis_accuracy=0.641 Gen_loss=0.940
# Epoch: >65, Batch: 546/546, Dis_loss=0.660, Dis_accuracy=0.656 Gen_loss=0.981
# Epoch: >66, Batch: 546/546, Dis_loss=0.637, Dis_accuracy=0.633 Gen_loss=0.772
# Epoch: >67, Batch: 546/546, Dis_loss=0.603, Dis_accuracy=0.625 Gen_loss=0.983
# Epoch: >68, Batch: 546/546, Dis_loss=0.650, Dis_accuracy=0.648 Gen_loss=1.167
# Epoch: >69, Batch: 546/546, Dis_loss=0.602, Dis_accuracy=0.656 Gen_loss=1.128
# Epoch: >70, Batch: 546/546, Dis_loss=0.667, Dis_accuracy=0.562 Gen_loss=0.858
# Epoch: >71, Batch: 546/546, Dis_loss=0.563, Dis_accuracy=0.711 Gen_loss=0.996
# Epoch: >72, Batch: 546/546, Dis_loss=0.598, Dis_accuracy=0.680 Gen_loss=1.061
# Epoch: >73, Batch: 546/546, Dis_loss=0.655, Dis_accuracy=0.625 Gen_loss=1.166
# Epoch: >74, Batch: 546/546, Dis_loss=0.572, Dis_accuracy=0.719 Gen_loss=1.298
# Epoch: >75, Batch: 546/546, Dis_loss=0.630, Dis_accuracy=0.633 Gen_loss=1.503
# Epoch: >76, Batch: 546/546, Dis_loss=0.518, Dis_accuracy=0.719 Gen_loss=1.351
# Epoch: >77, Batch: 546/546, Dis_loss=0.587, Dis_accuracy=0.695 Gen_loss=1.083
# Epoch: >78, Batch: 546/546, Dis_loss=0.622, Dis_accuracy=0.633 Gen_loss=1.222
# Epoch: >79, Batch: 546/546, Dis_loss=0.599, Dis_accuracy=0.664 Gen_loss=1.388
# Epoch: >80, Batch: 546/546, Dis_loss=0.607, Dis_accuracy=0.656 Gen_loss=1.167
# Epoch: >81, Batch: 546/546, Dis_loss=0.596, Dis_accuracy=0.688 Gen_loss=0.970
# Epoch: >82, Batch: 546/546, Dis_loss=0.567, Dis_accuracy=0.727 Gen_loss=0.939
# Epoch: >83, Batch: 546/546, Dis_loss=0.655, Dis_accuracy=0.609 Gen_loss=1.113
# Epoch: >84, Batch: 546/546, Dis_loss=0.623, Dis_accuracy=0.633 Gen_loss=0.852
# Epoch: >85, Batch: 546/546, Dis_loss=0.529, Dis_accuracy=0.742 Gen_loss=1.169
# Epoch: >86, Batch: 546/546, Dis_loss=0.563, Dis_accuracy=0.703 Gen_loss=1.035
# Epoch: >87, Batch: 546/546, Dis_loss=0.580, Dis_accuracy=0.703 Gen_loss=0.749
# Epoch: >88, Batch: 546/546, Dis_loss=0.646, Dis_accuracy=0.578 Gen_loss=0.867
# Epoch: >89, Batch: 546/546, Dis_loss=0.635, Dis_accuracy=0.617 Gen_loss=1.013
# Epoch: >90, Batch: 546/546, Dis_loss=0.594, Dis_accuracy=0.688 Gen_loss=1.140
# Epoch: >91, Batch: 546/546, Dis_loss=0.730, Dis_accuracy=0.586 Gen_loss=0.905
# Epoch: >92, Batch: 546/546, Dis_loss=0.610, Dis_accuracy=0.656 Gen_loss=1.227
# Epoch: >93, Batch: 546/546, Dis_loss=0.611, Dis_accuracy=0.656 Gen_loss=0.954
# Epoch: >94, Batch: 546/546, Dis_loss=0.608, Dis_accuracy=0.633 Gen_loss=1.034
# Epoch: >95, Batch: 546/546, Dis_loss=0.631, Dis_accuracy=0.594 Gen_loss=0.747
# Epoch: >96, Batch: 546/546, Dis_loss=0.554, Dis_accuracy=0.781 Gen_loss=0.986
# Epoch: >97, Batch: 546/546, Dis_loss=0.521, Dis_accuracy=0.711 Gen_loss=0.776
# Epoch: >98, Batch: 546/546, Dis_loss=0.638, Dis_accuracy=0.664 Gen_loss=0.995
# Epoch: >99, Batch: 546/546, Dis_loss=0.602, Dis_accuracy=0.672 Gen_loss=0.997
# Epoch: >100, Batch: 546/546, Dis_loss=0.611, Dis_accuracy=0.625 Gen_loss=1.007
